# %% [markdown]
# <a href="https://colab.research.google.com/github/KKhris17/basic-python-learning/blob/main/DSD32_Dec2025/BMI_Calculator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import time

# %%
def typing(str, delay=0.1):
  for char in str:
    print()
